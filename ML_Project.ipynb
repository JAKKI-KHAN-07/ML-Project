# %% [markdown]
# <a href="https://colab.research.google.com/github/JAKKI-KHAN-07/ML-Project/blob/main/ML_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img_path="/bill.webp"
img=cv2.imread(img_path)
print(img.shape)

img=cv2.resize(img,(900,700))
print(img.shape)

plt.imshow(img)
plt.show()
# Out:
# (1024, 768, 3)
# (700, 900, 3)

# %%
org=img.copy()
gray=cv2.cvtColor(org,cv2.COLOR_BGR2GRAY)
plt.imshow(gray,cmap="gray")
plt.show()

blurred=cv2.GaussianBlur(gray,(5,5),0)
plt.imshow(blurred,cmap="binary")
plt.show()

# %%
regen=cv2.cvtColor(blurred,cv2.COLOR_GRAY2BGR)
plt.imshow(org)
plt.show()

plt.imshow(regen)
plt.show()
